# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from datetime import date, datetime
from kaggle.api.kaggle_api_extended import KaggleApi
import zipfile

# %%
api = KaggleApi()
api.authenticate()
api.dataset_download_file('ealaxi/banksim1', file_name='bs140513_032310.csv')

with zipfile.ZipFile('bs140513_032310.csv.zip', 'r') as zipref:
    zipref.extractall()

# %%
archive_csv = pd.read_csv("C:/Users/rafael.marcelino/Documents/GitHub/PagSeguro_RM_FT/bs140513_032310.csv", header=0, quotechar="'")

# %%
archive_csv["data_aux"] = None
archive_csv["data_aux"] = np.where((archive_csv["step"] >= 0) & (archive_csv["step"] <= 30), date(2021,1,1), archive_csv["data_aux"])
archive_csv["data_aux"] = np.where((archive_csv["step"] >= 31) & (archive_csv["step"] <= 60), date(2021,2,1), archive_csv["data_aux"])
archive_csv["data_aux"] = np.where((archive_csv["step"] >= 61) & (archive_csv["step"] <= 90), date(2021,3,1), archive_csv["data_aux"])
archive_csv["data_aux"] = np.where((archive_csv["step"] >= 91) & (archive_csv["step"] <= 120), date(2021,4,1), archive_csv["data_aux"])
archive_csv["data_aux"] = np.where((archive_csv["step"] >= 121) & (archive_csv["step"] <= 150), date(2021,5,1), archive_csv["data_aux"])
archive_csv["data_aux"] = np.where((archive_csv["step"] >= 151) & (archive_csv["step"] <= 180), date(2021,6,1), archive_csv["data_aux"])

archive_csv
# Out:
#         step     customer age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151   4      M       28007   M348934600        28007
# 1          0   C352968107   2      M       28007   M348934600        28007
# 2          0  C2054744914   4      F       28007  M1823072687        28007
# 3          0  C1760612790   3      M       28007   M348934600        28007
# 4          0   C757503768   5      M       28007   M348934600        28007
# ...      ...          ...  ..    ...         ...          ...          ...
# 594638   179  C1753498738   3      F       28007  M1823072687        28007
# 594639   179   C650108285   4      F       28007  M1823072687        28007
# 594640   179   C123623130   2      F       28007   M349281107        28007
# 594641   179  C1499363341   5      M       28007  M1823072687        28007
# 594642   179   C616528518   4      F       28007  M1823072687        28007
#
#                  category  amount  fraud    data_aux
# ...

# %%
_fact_merchant_kpi = archive_csv.groupby(["data_aux", "merchant"], as_index=False).agg(tpv=('amount','sum'), qtd_transacoes=('merchant','count'))
_fact_merchant_kpi
# Out:
#        data_aux     merchant        tpv  qtd_transacoes
# 0    2021-01-01  M1053599405   54769.05             514
# 1    2021-01-01   M117188757      87.51               1
# 2    2021-01-01  M1198415165   31994.09             345
# 3    2021-01-01  M1294758098   11569.53              38
# 4    2021-01-01  M1313686961    2029.43              42
# ..          ...          ...        ...             ...
# 292  2021-06-01    M85975013  223333.21            5990
# 293  2021-06-01   M923029380    5557.67              28
# 294  2021-06-01   M933210764     421.77               7
# 295  2021-06-01    M97925176    6971.06             113
# 296  2021-06-01   M980657600   71166.51             239
#
# [297 rows x 4 columns]

# %%
archive_csv["gender"].where((archive_csv["gender"] == "M") | (archive_csv["gender"] == "M"), 'T', inplace=True)
archive_csv
# Out:
#         step     customer age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151   4      M       28007   M348934600        28007
# 1          0   C352968107   2      M       28007   M348934600        28007
# 2          0  C2054744914   4      T       28007  M1823072687        28007
# 3          0  C1760612790   3      M       28007   M348934600        28007
# 4          0   C757503768   5      M       28007   M348934600        28007
# ...      ...          ...  ..    ...         ...          ...          ...
# 594638   179  C1753498738   3      T       28007  M1823072687        28007
# 594639   179   C650108285   4      T       28007  M1823072687        28007
# 594640   179   C123623130   2      T       28007   M349281107        28007
# 594641   179  C1499363341   5      M       28007  M1823072687        28007
# 594642   179   C616528518   4      T       28007  M1823072687        28007
#
#                  category  amount  fraud    data_aux
# ...

# %%
archive_csv["mes"] = 0
archive_csv["mes"] = np.where((archive_csv["step"] >= 0) & (archive_csv["step"] <= 30), 1, archive_csv["mes"])
archive_csv["mes"] = np.where((archive_csv["step"] >= 31) & (archive_csv["step"] <= 60), 2, archive_csv["mes"])
archive_csv["mes"] = np.where((archive_csv["step"] >= 61) & (archive_csv["step"] <= 90), 3, archive_csv["mes"])
archive_csv["mes"] = np.where((archive_csv["step"] >= 91) & (archive_csv["step"] <= 120), 4, archive_csv["mes"])
archive_csv["mes"] = np.where((archive_csv["step"] >= 121) & (archive_csv["step"] <= 150), 5, archive_csv["mes"])
archive_csv["mes"] = np.where((archive_csv["step"] >= 151) & (archive_csv["step"] <= 180), 6, archive_csv["mes"])

archive_csv
# Out:
#         step     customer age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151   4      M       28007   M348934600        28007
# 1          0   C352968107   2      M       28007   M348934600        28007
# 2          0  C2054744914   4      T       28007  M1823072687        28007
# 3          0  C1760612790   3      M       28007   M348934600        28007
# 4          0   C757503768   5      M       28007   M348934600        28007
# ...      ...          ...  ..    ...         ...          ...          ...
# 594638   179  C1753498738   3      T       28007  M1823072687        28007
# 594639   179   C650108285   4      T       28007  M1823072687        28007
# 594640   179   C123623130   2      T       28007   M349281107        28007
# 594641   179  C1499363341   5      M       28007  M1823072687        28007
# 594642   179   C616528518   4      T       28007  M1823072687        28007
#
#                  category  amount  fraud    data_aux  mes
# ...

# %%
fact_merchant_kpi = archive_csv.groupby(by=["mes", "merchant"], as_index=False).agg(tpv=('amount','sum'), qtd_transacoes=('merchant','count'))
fact_merchant_kpi
# Out:
#      mes     merchant        tpv  qtd_transacoes
# 0      1  M1053599405   54769.05             514
# 1      1   M117188757      87.51               1
# 2      1  M1198415165   31994.09             345
# 3      1  M1294758098   11569.53              38
# 4      1  M1313686961    2029.43              42
# ..   ...          ...        ...             ...
# 292    6    M85975013  223333.21            5990
# 293    6   M923029380    5557.67              28
# 294    6   M933210764     421.77               7
# 295    6    M97925176    6971.06             113
# 296    6   M980657600   71166.51             239
#
# [297 rows x 4 columns]

# %%
dim_merchant_category = archive_csv.groupby(["merchant", "category"], as_index=False).any()[["merchant", "category"]]
dim_merchant_category.rename(columns={'merchant':'id_merchant'}, inplace=True)
dim_merchant_category
# Out:
#     id_merchant               category
# 0   M1053599405              es_health
# 1    M117188757                es_home
# 2   M1198415165   es_wellnessandbeauty
# 3   M1294758098             es_leisure
# 4   M1313686961            es_contents
# 5   M1352454843       es_hotelservices
# 6   M1353266412       es_hotelservices
# 7   M1400236507                es_home
# 8   M1416436880                es_tech
# 9    M151143676  es_barsandrestaurants
# 10  M1535107174   es_wellnessandbeauty
# 11  M1600850729             es_fashion
# 12  M1649169323       es_sportsandtoys
# 13  M1726401631              es_travel
# 14    M17379832       es_sportsandtoys
# 15  M1741626453       es_sportsandtoys
# 16  M1748431652   es_wellnessandbeauty
# 17  M1788569036       es_sportsandtoys
# 18  M1823072687      es_transportation
# 19  M1842530320                es_tech
# 20  M1872033263                es_home
# 21  M1873032707       es_hotelservices
# 22  M1888755466       es_otherservices
# ...

# %%
archive_csv["amount"].mask(archive_csv["amount"] == 0, None, inplace=True)
archive_csv
# Out:
#         step     customer age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151   4      M       28007   M348934600        28007
# 1          0   C352968107   2      M       28007   M348934600        28007
# 2          0  C2054744914   4      T       28007  M1823072687        28007
# 3          0  C1760612790   3      M       28007   M348934600        28007
# 4          0   C757503768   5      M       28007   M348934600        28007
# ...      ...          ...  ..    ...         ...          ...          ...
# 594638   179  C1753498738   3      T       28007  M1823072687        28007
# 594639   179   C650108285   4      T       28007  M1823072687        28007
# 594640   179   C123623130   2      T       28007   M349281107        28007
# 594641   179  C1499363341   5      M       28007  M1823072687        28007
# 594642   179   C616528518   4      T       28007  M1823072687        28007
#
#                  category  amount  fraud    data_aux  mes
# ...

# %%
archive_csv["amount"].replace(0, None, inplace=True)
archive_csv
# Out:
#         step     customer age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151   4      M       28007   M348934600        28007
# 1          0   C352968107   2      M       28007   M348934600        28007
# 2          0  C2054744914   4      T       28007  M1823072687        28007
# 3          0  C1760612790   3      M       28007   M348934600        28007
# 4          0   C757503768   5      M       28007   M348934600        28007
# ...      ...          ...  ..    ...         ...          ...          ...
# 594638   179  C1753498738   3      T       28007  M1823072687        28007
# 594639   179   C650108285   4      T       28007  M1823072687        28007
# 594640   179   C123623130   2      T       28007   M349281107        28007
# 594641   179  C1499363341   5      M       28007  M1823072687        28007
# 594642   179   C616528518   4      T       28007  M1823072687        28007
#
#                  category  amount  fraud    data_aux  mes
# ...

# %%
archive_csv["age"].replace('U', None, inplace=True)
archive_csv.age = archive_csv["age"].astype('int')
archive_csv
# Out:
#         step     customer  age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151    4      M       28007   M348934600        28007
# 1          0   C352968107    2      M       28007   M348934600        28007
# 2          0  C2054744914    4      T       28007  M1823072687        28007
# 3          0  C1760612790    3      M       28007   M348934600        28007
# 4          0   C757503768    5      M       28007   M348934600        28007
# ...      ...          ...  ...    ...         ...          ...          ...
# 594638   179  C1753498738    3      T       28007  M1823072687        28007
# 594639   179   C650108285    4      T       28007  M1823072687        28007
# 594640   179   C123623130    2      T       28007   M349281107        28007
# 594641   179  C1499363341    5      M       28007  M1823072687        28007
# 594642   179   C616528518    4      T       28007  M1823072687        28007
#
# ...

# %%
archive_csv["amount"].mean()
# Out:
# 37.893448992668915

# %%
teste = {"archive_csv": archive_csv}

# %%
teste["archive_csv"]
# Out:
#         step     customer  age gender  zipcodeOri     merchant  zipMerchant  \
# 0          0  C1093826151    4      M       28007   M348934600        28007
# 1          0   C352968107    2      M       28007   M348934600        28007
# 2          0  C2054744914    4      T       28007  M1823072687        28007
# 3          0  C1760612790    3      M       28007   M348934600        28007
# 4          0   C757503768    5      M       28007   M348934600        28007
# ...      ...          ...  ...    ...         ...          ...          ...
# 594638   179  C1753498738    3      T       28007  M1823072687        28007
# 594639   179   C650108285    4      T       28007  M1823072687        28007
# 594640   179   C123623130    2      T       28007   M349281107        28007
# 594641   179  C1499363341    5      M       28007  M1823072687        28007
# 594642   179   C616528518    4      T       28007  M1823072687        28007
#
# ...

# %%
data = date(2021,1,1)
data
# Out:
# datetime.date(2021, 1, 1)
